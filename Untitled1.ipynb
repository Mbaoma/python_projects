# %%
import pandas as pd
from matplotlib import plyplot as plt
x=[1,2,3]
y=[1,4,9]
plt.plot(x,y)
plt.xlabel("this is x")
plt.ylabel("this is y")
plt.show()
# Out:
# --------------------------------------------------------------------
# ImportError                        Traceback (most recent call last)
# <ipython-input-1-8ab736f4d1e9> in <module>
#       1 import pandas as pd
# ----> 2 from matplotlib import plyplot as plt
#       3 x=[1,2,3]
#       4 y=[1,4,9]
#       5 plt.plot(x,y)
#
# ImportError: cannot import name 'plyplot' from 'matplotlib' (/data/data/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.7/site-packages/matplotlib/__init__.py)

# %%
import pandas as pd
from matplotlib import pyplot as plt
x=[1,2,3]
y=[1,4,9]
plt.plot(x,y)
plt.show()
